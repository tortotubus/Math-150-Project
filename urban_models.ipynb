# %% [markdown]
# # Dataset

# %%
import zipfile
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# https://educationdata.urban.org/documentation/school-districts.html#overview

# %%
urban_zip = zipfile.ZipFile("/content/drive/MyDrive/Math 150 Project/datasets/Urban/Urban.zip")

# %% [markdown]
# https://educationdata.urban.org/documentation/school-districts.html#ccd_directory

# %%
# Load directory of school districts
districts_lea_directory = pd.read_csv(urban_zip.open('Urban/school-districts_lea_directory.csv'))

# Keep only data for 2018
districts_lea_directory_2018 = districts_lea_directory.query("year == 2018").copy(deep=True)

# Drop the year column
districts_lea_directory_2018.drop(labels=["year", "enrollment"], axis=1, inplace=True)

# Set index to leaid
districts_lea_directory_2018.set_index("leaid", inplace=True)
# Out:
# <ipython-input-93-e9a1ed38cffc>:2: DtypeWarning: Columns (4,9,10,11,12,14,15,27,28,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   districts_lea_directory = pd.read_csv(urban_zip.open('Urban/school-districts_lea_directory.csv'))

# %%
districts_lea_directory_2018.shape
# Out:
# (19840, 66)

# %% [markdown]
# https://educationdata.urban.org/documentation/school-districts.html#ccd-enrollment-by-grade

# %%
# Load district enrollment info for 2018
districts_ccd_lea_enrollment_2018 = pd.read_csv(urban_zip.open('Urban/schools_ccd_lea_enrollment_2018.csv'))

# Keep only enrollment totals for each district
districts_ccd_lea_enrollment_2018.query("grade == 99 & race == 99 & sex == 99", inplace=True)

# Drop special group columns
districts_ccd_lea_enrollment_2018.drop(labels=["grade", "race", "sex", "year", "fips"], axis=1, inplace=True)

# Set index to leaid
districts_ccd_lea_enrollment_2018.set_index("leaid", inplace=True)

# %% [markdown]
# https://educationdata.urban.org/documentation/school-districts.html#ccd_finance

# %%
# Open the district finance dataset
districts_ccd_finance = pd.read_csv(urban_zip.open('Urban/districts_ccd_finance.csv'),)

# Convert leaid column to integer
districts_ccd_finance['leaid'] = pd.to_numeric(districts_ccd_finance['leaid'], errors='coerce', downcast='integer')
districts_ccd_finance.dropna(subset=['leaid'], inplace=True)
districts_ccd_finance['leaid'] = districts_ccd_finance['leaid'].astype(int)

# Convert censusid column to integer
districts_ccd_finance['censusid'] = pd.to_numeric(districts_ccd_finance['censusid'], errors='coerce', downcast='integer')
districts_ccd_finance.dropna(subset=['censusid'], inplace=True)
districts_ccd_finance['censusid'] = districts_ccd_finance['censusid'].astype(int)

# Set index to leaid
districts_ccd_finance.set_index("leaid", inplace=True)

# Drop fips columns
districts_ccd_finance.drop(labels=["fips"], axis=1, inplace=True)

# Get only year 2018
districts_ccd_finance_2018 = districts_ccd_finance.query("year == 2018").copy(deep=True)
districts_ccd_finance_2018.drop(labels=["year"], axis=1, inplace=True)
# Out:
# <ipython-input-96-2c8b4efa9e13>:2: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   districts_ccd_finance = pd.read_csv(urban_zip.open('Urban/districts_ccd_finance.csv'),)

# %% [markdown]
# https://educationdata.urban.org/documentation/school-districts.html#edfacts_adjusted-cohort-graduation-rates

# %%
# Load graduation rates by district for 2018
districts_edfacts_grad_rates_2018 = pd.read_csv(urban_zip.open('Urban/districts_edfacts_grad_rates_2018.csv'))

# Keep only district total information (i.e. remove breakdown by special groups)
districts_edfacts_grad_rates_2018.query("race==99 & lep == 99 & homeless == 99 & disability == 99 & econ_disadvantaged == 99 & foster_care == 99", inplace=True)

# Drop columns for special groups
districts_edfacts_grad_rates_2018.drop(labels=["race", "lep", "homeless", "disability", "econ_disadvantaged", "foster_care"], axis=1, inplace=True)

# Drop columns in directory
districts_edfacts_grad_rates_2018.drop(labels=["leaid_num", "lea_name", "fips"], axis=1, inplace=True)

# Drop year column
districts_edfacts_grad_rates_2018.drop(labels=["year"], axis=1, inplace=True)

# Set index to leaid
districts_edfacts_grad_rates_2018.set_index("leaid", inplace=True)

# %% [markdown]
# https://educationdata.urban.org/documentation/school-districts.html#edfacts-state-assessments-by-grade

# %%
# Load districts' state assement data for 2018
districts_edfacts_assessments_2018 = pd.read_csv(urban_zip.open("Urban/districts_edfacts_assessments_2018.csv"))

# Keep only districts total information (i.e. remove breakdowns by special groups)
districts_edfacts_assessments_2018.query("grade_edfacts==99 & race==99 & sex == 99 & lep == 99 & homeless == 99 & migrant == 99 & disability == 99 & econ_disadvantaged == 99 & foster_care == 99 & military_connected == 99", inplace=True)

# Drop columns for special groups
districts_edfacts_assessments_2018.drop(labels=["grade_edfacts", "race", "sex", "lep", "homeless", "migrant", "disability", "econ_disadvantaged", "foster_care", "military_connected"], axis=1, inplace=True)

# Drop columns in directory
districts_edfacts_assessments_2018.drop(labels=["leaid_num", "lea_name", "fips"], axis=1, inplace=True)

# Drop year column
districts_edfacts_assessments_2018.drop(labels=["year"], axis=1, inplace=True)

# Set index to leaid
districts_edfacts_assessments_2018.set_index("leaid", inplace=True)

# %% [markdown]
# https://educationdata.urban.org/documentation/school-districts.html#saipe_poverty-estimates

# %%
# Load districts' small area income poverty estimates
districts_saipe = pd.read_csv(urban_zip.open("Urban/districts_saipe.csv"))

# Get only year 2018
districts_saipe_2018 = districts_saipe.query("year == 2018").copy(deep=True)

# Drop columns
districts_saipe_2018.drop(labels=["fips", "year", "district_id", "district_name"], axis=1, inplace=True)

# Set index to leaid
districts_saipe_2018.set_index("leaid", inplace=True)

dict(districts_saipe_2018.dtypes)
# Out:
# {'est_population_total': dtype('int64'),
#  'est_population_5_17': dtype('int64'),
#  'est_population_5_17_poverty': dtype('int64'),
#  'est_population_5_17_poverty_pct': dtype('float64'),
#  'est_population_5_17_pct': dtype('float64')}

# %% [markdown]
# ## Merging Datasets for 2018

# %%
# Create a combined dataset that contains information from all datasets
combined_dataset_2018 = districts_lea_directory_2018.copy(deep=True)
combined_dataset_2018 = pd.merge(combined_dataset_2018, districts_ccd_lea_enrollment_2018, on='leaid')
combined_dataset_2018 = pd.merge(combined_dataset_2018, districts_ccd_finance_2018, on='leaid')
combined_dataset_2018 = pd.merge(combined_dataset_2018, districts_edfacts_grad_rates_2018, on='leaid')
combined_dataset_2018 = pd.merge(combined_dataset_2018, districts_edfacts_assessments_2018, on='leaid')
combined_dataset_2018 = pd.merge(combined_dataset_2018, districts_saipe_2018, on='leaid')

# Drop non numeric values in numeric dataset
combined_dataset_2018_numeric = combined_dataset_2018.select_dtypes(include=[np.number])

dict(combined_dataset_2018.dtypes)
# Out:
# {'lea_name': dtype('O'),
#  'fips': dtype('float64'),
#  'state_leaid': dtype('O'),
#  'street_mailing': dtype('O'),
#  'city_mailing': dtype('O'),
#  'state_mailing': dtype('O'),
#  'zip_mailing': dtype('float64'),
#  'zip4_mailing': dtype('O'),
#  'street_location': dtype('O'),
#  'city_location': dtype('O'),
#  'state_location': dtype('O'),
#  'zip_location': dtype('float64'),
#  'zip4_location': dtype('O'),
#  'phone': dtype('O'),
#  'latitude': dtype('float64'),
#  'longitude': dtype('float64'),
#  'urban_centric_locale': dtype('float64'),
#  'cbsa': dtype('float64'),
#  'cbsa_type': dtype('float64'),
#  'csa': dtype('float64'),
#  'cmsa': dtype('float64'),
#  'necta': dtype('float64'),
#  'county_code': dtype('float64'),
#  'county_name': dtype('O'),
#  'congress_district_id': dtype('float64'),
#  'state_leg_district_lower': dtype('O'),
#  'state_leg_district_upper': dtype('O'),
#  'bureau_indian_education': dtype('float64'),
#  'supervisory_union_number': dtype('O'),
#  'agency_type': dtype('float64'),
#  'agency_level': dtype('float64'),
#  'boundary_change_indicator': dtype('float64'),
#  'agency_charter_indicator': dtype('float64'),
#  'lowest_grade_offered': dtype('float64'),
#  'highest_grade_offered': dtype('float64'),
#  'number_of_schools': dtype('float64'),
#  'spec_ed_students': dtype('float64'),
#  'english_language_learners': dtype('float64'),
#  'migrant_students': dtype('float64'),
#  'teachers_prek_fte': dtype('float64'),
#  'teachers_kindergarten_fte': dtype('float64'),
#  'teachers_elementary_fte': dtype('float64'),
#  'teachers_secondary_fte': dtype('float64'),
#  'teachers_ungraded_fte': dtype('float64'),
#  'teachers_total_fte': dtype('float64'),
#  'instructional_aides_fte': dtype('float64'),
#  'coordinators_fte': dtype('float64'),
#  'guidance_counselors_elem_fte': dtype('float64'),
#  'guidance_counselors_sec_fte': dtype('float64'),
#  'guidance_counselors_other_fte': dtype('float64'),
#  'guidance_counselors_total_fte': dtype('float64'),
#  'school_counselors_fte': dtype('float64'),
#  'librarian_specialists_fte': dtype('float64'),
#  'librarian_support_staff_fte': dtype('float64'),
#  'lea_administrators_fte': dtype('float64'),
#  'lea_admin_support_staff_fte': dtype('float64'),
#  'lea_staff_total_fte': dtype('float64'),
#  'school_administrators_fte': dtype('float64'),
#  'school_admin_support_staff_fte': dtype('float64'),
#  'school_staff_total_fte': dtype('float64'),
#  'school_psychologists_fte': dtype('float64'),
#  'support_staff_stu_wo_psych_fte': dtype('float64'),
#  'support_staff_other_fte': dtype('float64'),
#  'staff_total_fte': dtype('float64'),
#  'other_staff_fte': dtype('float64'),
#  'support_staff_students_fte': dtype('float64'),
#  'enrollment': dtype('float64'),
#  'censusid': dtype('int64'),
#  'rev_total': dtype('float64'),
#  'rev_fed_total': dtype('float64'),
#  'rev_fed_child_nutrition_act': dtype('int64'),
#  'rev_fed_state_title_i': dtype('float64'),
#  'rev_fed_state_idea': dtype('float64'),
#  'rev_fed_state_math_sci_teach': dtype('float64'),
#  'rev_fed_state_drug_free': dtype('float64'),
#  'rev_fed_state_vocational': dtype('float64'),
#  'rev_fed_state_bilingual_ed': dtype('float64'),
#  'rev_fed_state_other': dtype('int64'),
#  'rev_fed_direct_impact_aid': dtype('float64'),
#  'rev_fed_direct_indian_ed': dtype('float64'),
#  'rev_fed_direct_other': dtype('float64'),
#  'rev_fed_arra': dtype('float64'),
#  'rev_fed_nonspec': dtype('float64'),
#  'rev_state_total': dtype('float64'),
#  'rev_state_gen_formula_assist': dtype('float64'),
#  'rev_state_special_ed': dtype('float64'),
#  'rev_state_transportation': dtype('float64'),
#  'rev_state_staff_improve': dtype('float64'),
#  'rev_state_compens_basic_ed': dtype('float64'),
#  'rev_state_vocational_ed': dtype('float64'),
#  'rev_state_outlay_capital_debt': dtype('float64'),
#  'rev_state_bilingual_ed': dtype('float64'),
#  'rev_state_gifted_talented': dtype('float64'),
#  'rev_state_sch_lunch': dtype('float64'),
#  'rev_state_oth_prog': dtype('float64'),
#  'rev_state_employee_benefits': dtype('float64'),
#  'rev_state_not_employee_benefits': dtype('float64'),
#  'rev_state_nonspec': dtype('float64'),
#  'rev_local_total': dtype('float64'),
#  'rev_local_parent_govt': dtype('float64'),
#  'rev_local_prop_tax': dtype('float64'),
#  'rev_local_sales_tax': dtype('int64'),
#  'rev_local_utility_tax': dtype('int64'),
#  'rev_local_income_tax': dtype('int64'),
#  'rev_local_other_tax': dtype('int64'),
#  'rev_local_other_sch_systems': dtype('int64'),
#  'rev_local_cities_counties': dtype('int64'),
#  'rev_local_tuition_fees': dtype('float64'),
#  'rev_local_transportation_fees': dtype('float64'),
#  'rev_local_sch_lunch': dtype('int64'),
#  'rev_local_textbook_sales_rents': dtype('float64'),
#  'rev_local_dist_activ_receipts': dtype('float64'),
#  'rev_local_student_fees_nonspec': dtype('float64'),
#  'rev_local_oth_sales_serv': dtype('float64'),
#  'rev_local_interest_earnings': dtype('int64'),
#  'rev_local_rents_royalties': dtype('float64'),
#  'rev_local_property_sale': dtype('float64'),
#  'rev_local_fines_forfeits': dtype('float64'),
#  'rev_local_private_contrib': dtype('float64'),
#  'rev_local_misc': dtype('int64'),
#  'rev_nces': dtype('int64'),
#  'exp_total': dtype('float64'),
#  'exp_current_elsec_total': dtype('float64'),
#  'exp_current_state_local_funds': dtype('float64'),
#  'exp_current_federal_funds': dtype('float64'),
#  'exp_current_resa': dtype('float64'),
#  'exp_current_instruction_total': dtype('float64'),
#  'exp_current_supp_serve_total': dtype('float64'),
#  'exp_current_pupils': dtype('int64'),
#  'exp_current_instruc_staff': dtype('int64'),
#  'exp_current_general_admin': dtype('int64'),
#  'exp_current_sch_admin': dtype('int64'),
#  'exp_current_operation_plant': dtype('float64'),
#  'exp_current_student_transport': dtype('float64'),
#  'exp_current_bco': dtype('float64'),
#  'exp_current_supp_serv_nonspec': dtype('float64'),
#  'exp_current_other': dtype('int64'),
#  'exp_current_food_serv': dtype('int64'),
#  'exp_current_enterprise': dtype('float64'),
#  'exp_current_other_elsec': dtype('float64'),
#  'exp_nonelsec': dtype('int64'),
#  'exp_nonelsec_community_serv': dtype('float64'),
#  'exp_nonelsec_adult_education': dtype('float64'),
#  'exp_nonelsec_other': dtype('float64'),
#  'exp_current_arra': dtype('float64'),
#  'exp_textbooks': dtype('float64'),
#  'exp_utilities_energy': dtype('float64'),
#  'exp_tech_supplies_services': dtype('float64'),
#  'exp_tech_equipment': dtype('float64'),
#  'outlay_capital_total': dtype('float64'),
#  'outlay_capital_construction': dtype('float64'),
#  'outlay_capital_land_structures': dtype('int64'),
#  'outlay_capital_instruc_equip': dtype('float64'),
#  'outlay_capital_other_equip': dtype('float64'),
#  'outlay_capital_nonspec_equip': dtype('float64'),
#  'outlay_capital_arra': dtype('float64'),
#  'payments_private_schools': dtype('float64'),
#  'payments_charter_schools': dtype('float64'),
#  'payments_state_govt': dtype('int64'),
#  'payments_local_govt': dtype('int64'),
#  'payments_other_sch_system': dtype('int64'),
#  'salaries_total': dtype('float64'),
#  'salaries_instruction': dtype('float64'),
#  'salaries_teachers_regular_prog': dtype('float64'),
#  'salaries_teachers_sped': dtype('float64'),
#  'salaries_teachers_vocational': dtype('float64'),
#  'salaries_teachers_other_ed': dtype('float64'),
#  'salaries_supp_pupils': dtype('float64'),
#  'salaries_supp_instruc_staff': dtype('float64'),
#  'salaries_supp_general_admin': dtype('float64'),
#  'salaries_supp_sch_admin': dtype('float64'),
#  'salaries_supp_operation_plant': dtype('float64'),
#  'salaries_supp_stud_transport': dtype('float64'),
#  'salaries_supp_bco': dtype('float64'),
#  'salaries_food_service': dtype('float64'),
#  'benefits_employee_total': dtype('float64'),
#  'benefits_employee_instruction': dtype('float64'),
#  'benefits_supp_pupils': dtype('float64'),
#  'benefits_supp_instruc_staff': dtype('float64'),
#  'benefits_supp_general_admin': dtype('float64'),
#  'benefits_supp_sch_admin': dtype('float64'),
#  'benefits_supp_operation_plant': dtype('float64'),
#  'benefits_supp_stud_transport': dtype('float64'),
#  'benefits_supp_bco': dtype('float64'),
#  'benefits_food_service': dtype('float64'),
#  'benefits_enterprise_operations': dtype('float64'),
#  'debt_interest': dtype('int64'),
#  'debt_longterm_outstand_beg_FY': dtype('float64'),
#  'debt_longterm_issued_FY': dtype('float64'),
#  'debt_longterm_retired_FY': dtype('int64'),
#  'debt_longterm_outstand_end_FY': dtype('float64'),
#  'debt_shortterm_outstand_beg_FY': dtype('int64'),
#  'debt_shortterm_outstand_end_FY': dtype('float64'),
#  'assets_sinking_fund': dtype('int64'),
#  'assets_bond_fund': dtype('float64'),
#  'assets_other': dtype('float64'),
#  'enrollment_fall_responsible': dtype('float64'),
#  'enrollment_fall_school': dtype('float64'),
#  'cohort_num': dtype('float64'),
#  'grad_rate_low': dtype('float64'),
#  'grad_rate_high': dtype('float64'),
#  'grad_rate_midpt': dtype('float64'),
#  'read_test_num_valid': dtype('float64'),
#  'read_test_pct_prof_low': dtype('float64'),
#  'read_test_pct_prof_high': dtype('float64'),
#  'read_test_pct_prof_midpt': dtype('float64'),
#  'math_test_num_valid': dtype('float64'),
#  'math_test_pct_prof_low': dtype('float64'),
#  'math_test_pct_prof_high': dtype('float64'),
#  'math_test_pct_prof_midpt': dtype('float64'),
#  'est_population_total': dtype('int64'),
#  'est_population_5_17': dtype('int64'),
#  'est_population_5_17_poverty': dtype('int64'),
#  'est_population_5_17_poverty_pct': dtype('float64'),
#  'est_population_5_17_pct': dtype('float64')}

# %%
# Drop examples where enrollment is zero or NaN
combined_dataset_2018_numeric.query("enrollment != 0", inplace=True)
combined_dataset_2018_numeric.query("teachers_total_fte != 0", inplace=True)

# Drop
combined_dataset_2018_numeric[['read_test_num_valid', 'math_test_num_valid']].replace([-1, -2, -3], np.nan, inplace=True)
combined_dataset_2018_numeric.shape
# Out:
# <ipython-input-180-4f1bce06ad2d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_dataset_2018_numeric[['read_test_num_valid', 'math_test_num_valid']].replace([-1, -2, -3], np.nan, inplace=True)
# (10154, 219)

# %%
# Create per student capita version of column
def per_student_capita(df, col):
  for c in col:
    if c + "_per_student" not in df.columns:
      df[c + "_per_student"] = df[c] / df["enrollment"]
  return [c + "_per_student" for c in col]

def per_teacher_capita(df, col):
  for c in col:
    if c + "_per_teacher" not in df.columns:
      df[c + "_per_teacher"] = df[c] / df["teachers_fte"]
  return [c + "_per_teacher" for c in col]

# %%
col_student = []
# Revenue per student
col_student.extend([
    "rev_total",
    "rev_local_total",
    #"rev_local_sales_tax",
    #"rev_local_income_tax",
    "rev_state_total",
    "rev_fed_total"
])

# Expense per student
col_student.extend([
    "exp_total",
    "outlay_capital_total",
    #"exp_current_instruction_total",
    #"exp_current_supp_serve_total",
    #"exp_tech_equipment",
    #"outlay_capital_total",
])

# Staff per student
col_student.extend([
    "teachers_total_fte",
    #"instructional_aides_fte",
    #"school_counselors_fte",
    #"school_psychologists_fte",
    #"librarian_specialists_fte",
    #"staff_total_fte",
])

col_teacher = [
    "salaries_instruction",
    "benefits_employee_instruction"
]

# Create per student capita version
col_per_student = per_student_capita(combined_dataset_2018_numeric, col_student)
col_per_teacher = per_teacher_capita(combined_dataset_2018_numeric, col_teacher)

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Principal Component Regression

# %% [markdown]
# ### Principal Component Analysis

# %%
x_cols
# Out:
# ['rev_local_total_per_student',
#  'rev_state_total_per_student',
#  'rev_fed_total_per_student',
#  'exp_current_instruction_total_per_student',
#  'exp_current_supp_serve_total_per_student',
#  'teachers_total_fte_per_student',
#  'instructional_aides_fte_per_student']

# %%
from sklearn.cross_decomposition import PLSRegression
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt
import numpy as np

# Choose columns
y_cols = [
    # Graduation Rates
    "grad_rate_midpt",
    # State Assessments
    "read_test_pct_prof_midpt",
    "math_test_pct_prof_midpt",
]
x_cols = col_per_student + col_per_teacher

# Get data from the dataframe
data = combined_dataset_2018_numeric[x_cols + y_cols].dropna()

X = data[x_cols]
y = data[y_cols]

print(X.shape)
print(y.shape)

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0)

pcr = make_pipeline(StandardScaler(), PCA(n_components=.95), LinearRegression())
pcr.fit(X_train, y_train)
pca = pcr.named_steps["pca"]  # retrieve the PCA step of the pipeline

pls = PLSRegression(n_components=2)
pls.fit(X_train, y_train)

print(pcr.score(X_test, y_test))
print(pls.score(X_test, y_test))
# Out:
# (10146, 9)
# (10146, 3)
# 0.2161536687571607
# 0.21160724302223874

# %%
pred = pcr.predict(X_test)
np.sqrt(mean_squared_error(y_test, pred))
# Out:
# 13.618065416441963

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import scale


# Split the dataset into training (70%) and testing (30%) sets
X_train,X_test,y_train,y_test = train_test_split(
    X,y,
    test_size=0.3,
    random_state=0
)

# Scale the training and testing data
# X_reduced_train = pca.fit_transform(scale(X_train))
# X_reduced_test = pca.transform(scale(X_test))[:,:1]
X_reduced_train = pca.fit_transform(X_train)
X_reduced_test = pca.transform(X_test)[:,:1]

# Fit model on training data
regr = LinearRegression()
regr.fit(X_reduced_train[:,:1], y_train)

# Calculate MSE
pred = regr.predict(X_reduced_test)
np.sqrt(mean_squared_error(y_test, pred))
# Out:
# 15.228706238301386

# %%
y_test-pred
# Out:
#          grad_rate_midpt  read_test_pct_prof_midpt  math_test_pct_prof_midpt
# leaid
# 4816860         4.447854                -14.741751                -11.060041
# 3702280       -13.525915                 -5.823538                 -9.140590
# 2626400         7.602682                 -4.224483                  4.464531
# 1802490         9.325494                 20.639748                 16.315686
# 4828170       -10.327343                -18.678369                 -3.891705
# ...                  ...                       ...                       ...
# 2923270         7.333522                 -6.385282                  1.291035
# 625800          3.066749                -13.553523                -19.889791
# 4217370         3.032732                 13.316826                 -0.926698
# 4821030         9.821861                 -9.907853                 -0.208499
# 4700600         7.865610                 -5.926399                  3.727844
#
# [3039 rows x 3 columns]

# %% [markdown]
# ## Ordinary Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import scale

y_cols = [
    # Graduation Rates
    "grad_rate_midpt",
    # State Assessments
    "read_test_pct_prof_midpt",
    "math_test_pct_prof_midpt",
]
x_cols = [
    "rev_local_total",
    "rev_state_total",
    "rev_fed_total",
    "exp_current_instruction_total",
    "exp_current_supp_serve_total",
    "teachers_total_fte",
    "instructional_aides_fte",
]
x_cols = [c + "_per_student" for c in x_cols]

data = combined_dataset_2018_numeric[x_cols + y_cols].dropna()
print(data.shape)

X = data[x_cols]
y = data[y_cols]

# Split the dataset into training (70%) and testing (30%) sets
X_train,X_test,y_train,y_test = train_test_split(
    X,y,
    test_size=0.3,
    random_state=0
)

# Fit model on training data
regr = LinearRegression()
regr.fit(X_train, y_train)

# Calculate MSE
pred = regr.predict(X_test)
np.sqrt(mean_squared_error(y_test, pred))
# Out:
# (10130, 10)
# 13.670600874446238

# %%
regr.score(X,y)
# Out:
# 0.2364423441235076

# %%
regr.intercept_
# Out:
# array([106.01672904,  55.42826377,  50.02464202])

# %%
regr_df = pd.DataFrame(
    data=regr.coef_,
    columns=x_cols,
    index=y_cols,
)

regr_df
# Out:
#                           rev_local_total_per_student  \
# grad_rate_midpt                              0.000166
# read_test_pct_prof_midpt                     0.000307
# math_test_pct_prof_midpt                     0.000349
#
#                           rev_state_total_per_student  \
# grad_rate_midpt                             -0.000379
# read_test_pct_prof_midpt                    -0.000428
# math_test_pct_prof_midpt                    -0.000590
#
#                           rev_fed_total_per_student  \
# grad_rate_midpt                           -0.001131
# read_test_pct_prof_midpt                  -0.003566
# math_test_pct_prof_midpt                  -0.003152
#
#                           exp_current_instruction_total_per_student  \
# grad_rate_midpt                                            0.000738
# read_test_pct_prof_midpt                                   0.002030
# math_test_pct_prof_midpt                                   0.002137
#
#                           exp_current_supp_serve_total_per_student  \
# grad_rate_midpt                                          -0.001495
# read_test_pct_prof_midpt                                 -0.001054
# math_test_pct_prof_midpt                                 -0.001818
#
#                           teachers_total_fte_per_student  \
# grad_rate_midpt                              -203.940847
# read_test_pct_prof_midpt                     -144.523005
# math_test_pct_prof_midpt                      -91.751861
#
#                           instructional_aides_fte_per_student
# grad_rate_midpt                                     37.395552
# read_test_pct_prof_midpt                           -19.319403
# math_test_pct_prof_midpt                           -12.814507

# %%
regr_residuals = abs(pred - y_test)
regr_residuals
# Out:
#          grad_rate_midpt  read_test_pct_prof_midpt  math_test_pct_prof_midpt
# leaid
# 4816860         4.735737                 12.468304                  9.448528
# 3702280         1.908212                  1.967573                  0.963533
# 2626400         1.250436                 10.795352                  2.604109
# 1802490         4.361488                 17.284854                 13.676229
# 4828170         2.673937                  7.721788                  6.475841
# ...                  ...                       ...                       ...
# 2923270         6.517396                  5.217351                  0.696474
# 625800          0.537979                 18.415132                 22.659849
# 4217370         3.421833                  6.784192                  6.852107
# 4821030         8.258651                  8.409719                  0.506431
# 4700600         5.243131                  7.308041                  1.671207
#
# [3039 rows x 3 columns]
